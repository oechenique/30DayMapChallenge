# %% [markdown]
# # 🗾 #30DayMapChallenge 2024 - Day 12: Time and Space
#
# ## フクシマの記憶: Mapping Fukushima's Timeline 2010-2023 ⏳

# %% [markdown]
# ### 1. Understanding Time Series Analysis in Earth Observation 地球観測
#
# #### The Power of Time in Remote Sensing
# * Satellite imagery as a witness to environmental change
# * Historical documentation of natural events
# * Monitoring recovery and reconstruction efforts
# * Understanding long-term environmental impacts
#
# #### Time Series Components in this Analysis
# * **Pre-event** (2010-early 2011): Baseline conditions
# * **Impact Period** (March 2011): Immediate aftermath
# * **Recovery Years** (2011-2023): Ongoing restoration
# * **Current Status**: Present-day situation

# %% [markdown]
# ### 2. The Great Tōhoku Earthquake and Tsunami 東日本大震災
#
# #### March 11, 2011: A Day That Changed Japan
# * 14:46 JST: 9.0 magnitude earthquake (東北地方太平洋沖地震)
# * Triggered one of the most powerful tsunamis in recorded history
# * Waves reaching heights of up to 40.5 meters
# * Led to the Fukushima Daiichi nuclear disaster (福島第一原子力発電所事故)
#
# #### Impact Statistics
# * Over 15,899 lives lost
# * More than 2,529 people still missing
# * Extensive infrastructure damage
# * Creation of evacuation zones (避難区域)

# %% [markdown]
# ### 3. Time Series Analysis Purpose 分析目的
#
# Our mapping helps to:
# * Document environmental changes
# * Track reconstruction efforts
# * Monitor affected areas
# * Preserve historical memory
# * Support ongoing research

# %% [markdown]
# ### 4. Data Processing Methodology 処理方法
#
# #### Data Sources
# * Landsat imagery
# * Sentinel-2 data
# * MODIS observations
# * Local environmental monitoring
#
# #### Processing Steps
# 1. **データ収集 (Data Collection)**
#    * Historical satellite imagery
#    * Environmental readings
#    * Ground truth data
#    * Recovery progress reports
#
# 2. **分析手順 (Analysis Process)**
#    * Image preprocessing
#    * Change detection
#    * Time series analysis
#    * Validation

# %% [markdown]
# ### 5. Visual Elements 視覚要素
#
# #### Temporal Visualization
# * Color schemes representing different time periods
# * Change detection highlighting
# * Progressive reconstruction mapping
# * Environmental impact indicators
#
# #### Map Components
# * Base satellite imagery
# * Temporal overlays
# * Impact zones
# * Recovery indicators

# %% [markdown]
# ### 6. Code Implementation 実装

# %%
# Install the ffmpeg-python library for handling video and audio processing
# !pip install ffmpeg-python -q

# %%
# ADD your Google Earth Engine project ID here
gee_project_id = 'ee-gastonechenique'  # Replace with your specific project ID 'your-google-project-id'

# Import Google Colab authentication library
from google.colab import auth
auth.authenticate_user(project_id=gee_project_id)  # Authenticate using your Google project ID

# Import geemap and other necessary libraries
import geemap
import ee
import folium

# Authenticate and initialize Earth Engine
ee.Authenticate()
ee.Initialize()

# %%
# Define the region of interest for Fukushima
fukushima_region = ee.Geometry.Point([141.032, 37.421]).buffer(20000)  # 20 km buffer around the Fukushima nuclear plant

# Function to get an annual quality composite image with a quality filter
def get_quality_composite(year, num_years=1):
    start_date = f'{year}-01-01'
    end_date = f'{year + num_years - 1}-12-31'

    # Landsat 8 collection (use Landsat 5 for earlier years if needed)
    collection = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2') \
                 .filterBounds(fukushima_region) \
                 .filterDate(start_date, end_date) \
                 .filterMetadata('CLOUD_COVER', 'less_than', 20)

    # Quality mask based on NDVI to remove images with low vegetation (indicating clouds or shadows)
    def mask_quality(image):
        ndvi = image.normalizedDifference(['SR_B5', 'SR_B4']).rename('NDVI')
        mask = ndvi.gt(0.1)  # Filter out pixels with low NDVI, indicating shadows or clouds
        cloud_mask = image.select('QA_PIXEL').bitwiseAnd(int('11111', 2)).eq(0)
        return image.updateMask(cloud_mask.And(mask))

    # Apply the quality mask and calculate the median of the period
    composite = collection.map(mask_quality).median()
    return composite.multiply(0.0000275).add(-0.2).visualize(bands=['SR_B4', 'SR_B3', 'SR_B2'], min=0, max=0.3)

# Create a list of high-quality composite images for each year
years = list(range(2010, 2023))  # From 2011 to capture changes after the nuclear disaster
images = [get_quality_composite(year, num_years=2).set('label', str(year)) for year in years]

# Set up the output directory for the GIF
import os
out_dir = os.path.join(os.path.expanduser("~"), "Downloads")
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# Generate the GIF
Map = geemap.Map(center=[37.421, 141.032], zoom=10)
label = "Post-Disaster Changes in Fukushima, Japan"
Map.add_landsat_ts_gif(
    roi=fukushima_region,
    out_gif=os.path.join(out_dir, "fukushima_timelapse.gif"),
    start_year=2010,
    end_year=2023,
    bands=["Red", "Green", "Blue"],
    font_color="white",
    frames_per_second=2,
    font_size=30,
    progress_bar_color="blue",
    label=label,
    apply_fmask=True  # Keep the cloud mask applied
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL...
# ...
# Please wait ...
# The GIF image has been saved to: /root/Downloads/fukushima_timelapse.gif
# Adding GIF to the map ...
# The timelapse has been added to the map.

# %%
# Display the map
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[37.421, 141.032], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDat…

# %% [markdown]
# ### 7. Cultural Context: "The Days" ザ・デイズ
#
# Netflix's "The Days" (2023) provides important context:
# * Dramatizes the events at Fukushima Daiichi
# * Shows the human side of the disaster
# * Highlights the courage of the "Fukushima 50"
# * Reminds us of the importance of historical documentation

# %% [markdown]
# ### 8. Remembrance and Recovery 記憶と復興
#
# #### Progress Made
# * Decontamination efforts
# * Community rebuilding
# * Infrastructure restoration
# * Environmental monitoring
#
# #### Ongoing Challenges
# * Long-term environmental impacts
# * Community displacement
# * Economic recovery
# * Public health monitoring

# %% [markdown]
# ### 9. Resources and References 参考資料
# * [Japan Meteorological Agency](https://www.jma.go.jp/)
# * [Fukushima Prefecture Recovery Site](https://www.pref.fukushima.lg.jp/)
# * [NASA Earth Observatory](https://earthobservatory.nasa.gov/)
# * [Google Earth Engine Documentation](https://developers.google.com/earth-engine/)

# %% [markdown]
# ### 10. Acknowledgment (追悼)
# This map is dedicated to:
# * The victims and survivors (犠牲者と生存者)
# * The first responders (救助隊)
# * The Fukushima 50 (フクシマ50)
# * All those who continue to work towards recovery (復興に向けて)

# %% [markdown]
# ### さようなら (Goodbye) Until Tomorrow! 🌏
# Tomorrow brings another mapping challenge, but today we remember.
#
# "Time reveals all things" - 時が全てを明らかにする

# %%
#@title Follow Me!
# %%html

<div style="background: linear-gradient(90deg, #1a1a1a, #2d2d2d); color: white; padding: 2rem; border-radius: 10px; font-family: 'Roboto', sans-serif; margin-top: 2rem;">
    <h2 style="text-align: center; margin-bottom: 1rem;">
        <span style="display: block; color: white; font-size: 2.7rem; margin-bottom: 0.5rem;">ありがとうございます！</span>
        <span style="display: block; color: white; font-size: 1.8rem;">🌍 Thank you for making it this far! 🎌</span>
    </h2>

    <p style="font-size: 1.2rem; margin-bottom: 1.5rem;">If you're interested in the world of geoinformatics and want to keep learning, connect with me! | 一緒に学びましょう！</p>

    <div style="display: flex; flex-wrap: wrap; gap: 1rem; margin-bottom: 1rem;">
        <a href="https://x.com/GastonEchenique" target="_blank" style="text-decoration: none; color: white; display: flex; align-items: center; background: #1DA1F2; padding: 0.5rem 1rem; border-radius: 5px; transition: transform 0.2s;">
            <svg style="width: 24px; height: 24px; margin-right: 0.5rem;" viewBox="0 0 24 24" fill="currentColor">
                <path d="M18.244 2.25h3.308l-7.227 8.26 8.502 11.24H16.17l-5.214-6.817L4.99 21.75H1.68l7.73-8.835L1.254 2.25H8.08l4.713 6.231zm-1.161 17.52h1.833L7.084 4.126H5.117z"/>
            </svg>
            <span>@GastonEchenique</span>
        </a>

        <a href="https://www.linkedin.com/in/gaston-echenique/" target="_blank" style="text-decoration: none; color: white; display: flex; align-items: center; background: #0A66C2; padding: 0.5rem 1rem; border-radius: 5px; transition: transform 0.2s;">
            <svg style="width: 24px; height: 24px; margin-right: 0.5rem;" viewBox="0 0 24 24" fill="currentColor">
                <path d="M20.447 20.452h-3.554v-5.569c0-1.328-.027-3.037-1.852-3.037-1.853 0-2.136 1.445-2.136 2.939v5.667H9.351V9h3.414v1.561h.046c.477-.9 1.637-1.85 3.37-1.85 3.601 0 4.267 2.37 4.267 5.455v6.286zM5.337 7.433c-1.144 0-2.063-.926-2.063-2.065 0-1.138.92-2.063 2.063-2.063 1.14 0 2.064.925 2.064 2.063 0 1.139-.925 2.065-2.064 2.065zm1.782 13.019H3.555V9h3.564v11.452zM22.225 0H1.771C.792 0 0 .774 0 1.729v20.542C0 23.227.792 24 1.771 24h20.451C23.2 24 24 23.227 24 22.271V1.729C24 .774 23.2 0 22.222 0h.003z"/>
            </svg>
            <span>Gastón Echenique</span>
        </a>

        <a href="https://github.com/oechenique" target="_blank" style="text-decoration: none; color: white; display: flex; align-items: center; background: #333; padding: 0.5rem 1rem; border-radius: 5px; transition: transform 0.2s;">
            <svg style="width: 24px; height: 24px; margin-right: 0.5rem;" viewBox="0 0 24 24" fill="currentColor">
299-.435 1.999-.597zm9.924 0c.7.163 1.362.367 1.999.597-.931.903-2.034 1.625-3.257 2.116.489-.832.915-1.737 1.258-2.713zm.553-1.917c.27-1.163.442-2.386.501-3.651h3.934c-.167 1.672-.748 3.223-1.638 4.551-.877-.358-1.81-.664-2.797-.9zm.501-5.651c-.058-1.251-.229-2.46-.492-3.611.992-.237 1.929-.546 2.809-.907.877 1.321 1.451 2.86 1.616 4.518h-3.933z"/>
            </svg>
            <span>GeoAnalytics</span>
        </a>

        <a href="https://discord.com/users/gastonechenique" target="_blank" style="text-decoration: none; color: white; display: flex; align-items: center; background: #5865F2; padding: 0.5rem 1rem; border-radius: 5px; transition: transform 0.2s;">
            <svg style="width: 24px; height: 24px; margin-right: 0.5rem;" viewBox="0 0 24 24" fill="currentColor">
                <path d="M20.317 4.37a19.791 19.791 0 0 0-4.885-1.515a.074.074 0 0 0-.079.037c-.21.375-.444.864-.608 1.25a18.27 18.27 0 0 0-5.487 0a12.64 12.64 0 0 0-.617-1.25a.077.077 0 0 0-.079-.037A19.736 19.736 0 0 0 3.677 4.37a.07.07 0 0 0-.032.027C.533 9.046-.32 13.58.099 18.057a.082.082 0 0 0 .031.057a19.9 19.9 0 0 0 5.993 3.03a.078.078 0 0 0 .084-.028a14.09 14.09 0 0 0 1.226-1.994a.076.076 0 0 0-.041-.106a13.107 13.107 0 0 1-1.872-.892a.077.077 0 0 1-.008-.128a10.2 10.2 0 0 0 .372-.292a.074.074 0 0 1 .077-.01c3.928 1.793 8.18 1.793 12.062 0a.074.074 0 0 1 .078.01c.12.098.246.198.373.292a.077.077 0 0 1-.006.127a12.299 12.299 0 0 1-1.873.892a.077.077 0 0 0-.041.107c.36.698.772 1.362 1.225 1.993a.076.076 0 0 0 .084.028a19.839 19.839 0 0 0 6.002-3.03a.077.077 0 0 0 .032-.054c.5-5.177-.838-9.674-3.549-13.66a.061.061 0 0 0-.031-.03zM8.02 15.33c-1.183 0-2.157-1.085-2.157-2.419c0-1.333.956-2.419 2.157-2.419c1.21 0 2.176 1.096 2.157 2.42c0 1.333-.956 2.418-2.157 2.418zm7.975 0c-1.183 0-2.157-1.085-2.157-2.419c0-1.333.955-2.419 2.157-2.419c1.21 0 2.176 1.096 2.157 2.42c0 1.333-.946 2.418-2.157 2.418z"/>
            </svg>
            <span>Gaston | ガストン</span>
        </a>
    </div>

    <p style="font-size: 1rem; color: #888;">💡 頑張りましょう！Don't miss more content about GIS, Data Science and Geoinformatics!</p>

    <div style="margin-top: 1rem; padding-top: 1rem; border-top: 1px solid #444; font-size: 0.9rem; color: #666;">
        Made with 🗺️ & 💻 by Gaston Echenique | エチェニケ・ガストン
    </div>
</div>
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="background: linear-gradient(90deg, #1a1a1a, #2d2d2d); color: white; padding: 2rem; border-radius: 10px; font-family: 'Roboto', sans-serif; margin-top: 2rem;">
# ...
